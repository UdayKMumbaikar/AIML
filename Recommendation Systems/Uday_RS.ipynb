# %% [markdown]
# This Case Study is targeted to build a recommendation system
# based on individual consumer’s behaviour or choice.
# DATA DESCRIPTION:
# • author : name of the person who gave the rating
# • country : country the person who gave the rating belongs to
# • data : date of the rating
# • domain: website from which the rating was taken from
# • extract: rating content
# • language: language in which the rating was given
# • product: name of the product/mobile phone for which the rating was given
# • score: average rating for the phone
# • score_max: highest rating given for the phone
# • source: source from where the rating was taken

# %%
import os
import numpy as np  
import pandas as pd
#  To enable plotting graphs in Jupyter notebook
# %matplotlib inline 
# Numerical libraries
 

# importing ploting libraries
import matplotlib.pyplot as plt   
import matplotlib.style
plt.style.use('classic')

#importing seaborn for statistical plots
import seaborn as sns

from scipy.stats import zscore

# %% [markdown]
# Reading give csv files

# %%
data1 = pd.read_csv("phone_user_review_file_1.csv",encoding='ISO-8859–1')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374910 entries, 0 to 374909
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   phone_url  374910 non-null  object
#  1   date       374910 non-null  object
#  2   lang       374910 non-null  object
#  3   country    374910 non-null  object
#  4   source     374910 non-null  object
#  5   domain     374910 non-null  object
#  6   score      366691 non-null  float64
#  7   score_max  366691 non-null  float64
#  8   extract    371934 non-null  object
#  9   author     371641 non-null  object
#  10  product    374910 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 31.5+ MB

# %%
data2 = pd.read_csv("phone_user_review_file_2.csv",encoding='ISO-8859–1') 
data3 = pd.read_csv("phone_user_review_file_3.csv",encoding='ISO-8859–1') 
data4 = pd.read_csv("phone_user_review_file_4.csv",encoding='ISO-8859–1') 
data5 = pd.read_csv("phone_user_review_file_5.csv",encoding='ISO-8859–1') 
data6 = pd.read_csv("phone_user_review_file_6.csv",encoding='ISO-8859–1')

# %%
data1.head(10)
# Out:
#                         phone_url       date lang country            source  \
# 0  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us  Verizon Wireless
# 1  /cellphones/samsung-galaxy-s8/  4/28/2017   en      us       Phone Arena
# 2  /cellphones/samsung-galaxy-s8/   5/4/2017   en      us            Amazon
# 3  /cellphones/samsung-galaxy-s8/   5/2/2017   en      us           Samsung
# 4  /cellphones/samsung-galaxy-s8/  5/11/2017   en      us  Verizon Wireless
# 5  /cellphones/samsung-galaxy-s8/  5/10/2017   en      us  Verizon Wireless
# 6  /cellphones/samsung-galaxy-s8/  5/10/2017   en      us  Verizon Wireless
# 7  /cellphones/samsung-galaxy-s8/  5/10/2017   en      us  Verizon Wireless
# 8  /cellphones/samsung-galaxy-s8/  5/10/2017   en      us  Verizon Wireless
# 9  /cellphones/samsung-galaxy-s8/  5/10/2017   en      us  Verizon Wireless
#
#                 domain  score  score_max  \
# 0  verizonwireless.com   10.0       10.0
# 1       phonearena.com   10.0       10.0
# ...

# %%
data2.head(10)
# Out:
#                     phone_url        date lang country  source        domain  \
# 0  /cellphones/leagoo-lead-7/   4/15/2015   en      us  Amazon    amazon.com
# 1  /cellphones/leagoo-lead-7/   5/23/2015   en      gb  Amazon  amazon.co.uk
# 2  /cellphones/leagoo-lead-7/   4/27/2015   en      gb  Amazon  amazon.co.uk
# 3  /cellphones/leagoo-lead-7/   4/22/2015   en      gb  Amazon  amazon.co.uk
# 4  /cellphones/leagoo-lead-7/   4/18/2015   en      gb  Amazon  amazon.co.uk
# 5  /cellphones/leagoo-lead-7/   4/14/2015   en      us  Amazon    amazon.com
# 6  /cellphones/leagoo-lead-7/    4/1/2015   en      gb  Amazon  amazon.co.uk
# 7  /cellphones/leagoo-lead-7/   11/6/2015   it      it  Amazon     amazon.it
# 8  /cellphones/leagoo-lead-7/  10/26/2015   it      it  Amazon     amazon.it
# 9  /cellphones/leagoo-lead-7/   9/19/2015   it      it  Amazon     amazon.it
#
#    score  score_max                                            extract  \
# ...

# %%
data3.head(10)
# Out:
#                                          phone_url       date lang country  \
# 0  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/  11/7/2015   pt      br
# 1  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/  10/2/2015   pt      br
# 2  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/   9/2/2015   pt      br
# 3  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/   9/2/2015   pt      br
# 4  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/   9/1/2015   pt      br
# 5  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/   9/1/2015   pt      br
# 6  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/   8/3/2015   pt      br
# 7  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/  7/29/2015   pt      br
# 8  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/  7/24/2015   pt      br
# 9  /cellphones/samsung-galaxy-s-iii-slim-sm-g3812/  7/21/2015   pt      br
#
#       source            domain  score  score_max  \
# 0  Submarino  submarino.com.br    6.0       10.0
# ...

# %%
data4.head(10)
# Out:
#                                     phone_url        date lang country  \
# 0  /cellphones/samsung-s7262-duos-galaxy-ace/   3/11/2015   en      us
# 1  /cellphones/samsung-s7262-duos-galaxy-ace/  17/11/2015   en      in
# 2  /cellphones/samsung-s7262-duos-galaxy-ace/  29/10/2015   en      in
# 3  /cellphones/samsung-s7262-duos-galaxy-ace/  29/10/2015   en      in
# 4  /cellphones/samsung-s7262-duos-galaxy-ace/  29/10/2015   en      in
# 5  /cellphones/samsung-s7262-duos-galaxy-ace/  27/10/2015   en      in
# 6  /cellphones/samsung-s7262-duos-galaxy-ace/  27/10/2015   en      us
# 7  /cellphones/samsung-s7262-duos-galaxy-ace/  26/10/2015   en      in
# 8  /cellphones/samsung-s7262-duos-galaxy-ace/  25/10/2015   en      in
# 9  /cellphones/samsung-s7262-duos-galaxy-ace/  21/10/2015   en      in
#
#    source      domain  score  score_max  \
# 0  Amazon  amazon.com    2.0       10.0
# 1  Zopper  zopper.com   10.0       10.0
# 2  Amazon   amazon.in    4.0       10.0
# ...

# %%
data5.head(10)
# Out:
#                     phone_url        date lang country      source  \
# 0  /cellphones/karbonn-k1616/   7/13/2016   en      in  91 Mobiles
# 1  /cellphones/karbonn-k1616/   7/13/2016   en      in  91 Mobiles
# 2  /cellphones/karbonn-k1616/   7/13/2016   en      in  91 Mobiles
# 3  /cellphones/karbonn-k1616/   4/25/2014   en      in     Naaptol
# 4  /cellphones/karbonn-k1616/   4/23/2013   en      in     Naaptol
# 5  /cellphones/karbonn-k1616/   2/24/2013   en      in     Naaptol
# 6  /cellphones/karbonn-k1616/   2/23/2013   en      in     Naaptol
# 7  /cellphones/karbonn-k1616/    2/7/2013   en      in     Naaptol
# 8  /cellphones/karbonn-k1616/   1/12/2013   en      in     Naaptol
# 9  /cellphones/karbonn-k1616/  10/13/2012   en      in     Naaptol
#
#           domain  score  score_max  \
# 0  91mobiles.com    2.0       10.0
# 1  91mobiles.com    6.0       10.0
# 2  91mobiles.com    4.0       10.0
# 3    naaptol.com   10.0       10.0
# 4    naaptol.com   10.0       10.0
# ...

# %%
data6.head(10)
# Out:
#                                 phone_url        date lang country  \
# 0  /cellphones/samsung-instinct-sph-m800/   9/16/2011   en      us
# 1  /cellphones/samsung-instinct-sph-m800/   2/13/2014   en      us
# 2  /cellphones/samsung-instinct-sph-m800/  12/30/2011   en      us
# 3  /cellphones/samsung-instinct-sph-m800/  10/18/2008   en      us
# 4  /cellphones/samsung-instinct-sph-m800/    9/6/2008   en      us
# 5  /cellphones/samsung-instinct-sph-m800/   1/28/2009   en      us
# 6  /cellphones/samsung-instinct-sph-m800/   7/25/2008   en      us
# 7  /cellphones/samsung-instinct-sph-m800/   5/12/2015   en      us
# 8  /cellphones/samsung-instinct-sph-m800/   4/26/2015   en      us
# 9  /cellphones/samsung-instinct-sph-m800/   9/11/2014   en      us
#
#                       source             domain  score  score_max  \
# 0                Phone Arena     phonearena.com    8.0       10.0
# 1                     Amazon         amazon.com    6.0       10.0
# ...

# %% [markdown]
# Checking scores with 0 values in data

# %%
c=0
for m in data1['score']:
    if m==0:
        c=c+1
        print(c)
        
c=0
for m in data2['score']:
    if m==0:
        c=c+1
        print(c)
c=0
for m in data3['score']:
    if m==0:
        c=c+1
        print(c)
        
c=0
for m in data4['score']:
    if m==0:
        c=c+1
        print(c)        

c=0
for m in data5['score']:
    if m==0:
        c=c+1
        print(c)        
c=0
for m in data6['score']:
    if m==0:
        c=c+1
        print(c)

# %% [markdown]
# Did not found any score with 0 value
#
# Rounding off scores to the nearest integers

# %%
data1['score']=data1['score'].round()
data2['score']=data2['score'].round()
data3['score']=data3['score'].round()
data4['score']=data4['score'].round()
data5['score']=data5['score'].round()
data6['score']=data6['score'].round()

# %%
print(data2.info())
print(data3.info())
print(data4.info())
print(data5.info())
print(data6.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114925 entries, 0 to 114924
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   phone_url  114925 non-null  object
#  1   date       114925 non-null  object
#  2   lang       114925 non-null  object
#  3   country    114925 non-null  object
#  4   source     114925 non-null  object
#  5   domain     114925 non-null  object
#  6   score      112166 non-null  float64
#  7   score_max  112166 non-null  float64
#  8   extract    113965 non-null  object
#  9   author     113290 non-null  object
#  10  product    114925 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 9.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312961 entries, 0 to 312960
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   phone_url  312961 non-null  object
# ...

# %%
print(data1.isnull().sum())
# Out:
# phone_url       0
# date            0
# lang            0
# country         0
# source          0
# domain          0
# score        8219
# score_max    8219
# extract      2976
# author       3269
# product         0
# dtype: int64

# %% [markdown]
# Found null values in data

# %% [markdown]
# Checking for values with score max greater than 10

# %%
print(data1[['score_max']].loc[data1['score_max']<10])
print(data1[['score_max']].loc[data1['score_max']>10])
# Out:
# Empty DataFrame
# Columns: [score_max]
# Index: []
# Empty DataFrame
# Columns: [score_max]
# Index: []

# %% [markdown]
# Did not found any score max greater than and less than 10
#
# Filling missing score with 0 and missing score max with

# %%
data1['score_max']=data1['score_max'].fillna(10)
data1['score']=data1['score'].fillna(0)
data1['author']=data1['author'].fillna('NA')
data1['extract']=data1['extract'].fillna('NA')

# %%
print(data1.isnull().sum())
# Out:
# phone_url    0
# date         0
# lang         0
# country      0
# source       0
# domain       0
# score        0
# score_max    0
# extract      0
# author       0
# product      0
# dtype: int64

# %%
data2['score_max']=data2['score_max'].fillna(10)
data2['score']=data2['score'].fillna(0)
data2['author']=data2['author'].fillna('NA')
data2['extract']=data2['extract'].fillna('NA')
print(data2.isnull().sum())
# Out:
# phone_url    0
# date         0
# lang         0
# country      0
# source       0
# domain       0
# score        0
# score_max    0
# extract      0
# author       0
# product      0
# dtype: int64

# %%
data3['score_max']=data3['score_max'].fillna(10)
data3['score']=data3['score'].fillna(0)
data3['author']=data3['author'].fillna('NA')
data3['extract']=data3['extract'].fillna('NA')
data3=data3.dropna(axis=0)
print(data3.isnull().sum())
# Out:
# phone_url    0
# date         0
# lang         0
# country      0
# source       0
# domain       0
# score        0
# score_max    0
# extract      0
# author       0
# product      0
# dtype: int64

# %%
data4['score_max']=data4['score_max'].fillna(10)
data4['score']=data4['score'].fillna(0)
data4['author']=data4['author'].fillna('NA')
data4['extract']=data4['extract'].fillna('NA')
print(data4.isnull().sum())
# Out:
# phone_url    0
# date         0
# lang         0
# country      0
# source       0
# domain       0
# score        0
# score_max    0
# extract      0
# author       0
# product      0
# dtype: int64

# %%
data5['score_max']=data5['score_max'].fillna(10)
data5['score']=data5['score'].fillna(0)
data5['author']=data5['author'].fillna('NA')
data5['extract']=data5['extract'].fillna('NA')
print(data5.isnull().sum())
# Out:
# phone_url    0
# date         0
# lang         0
# country      0
# source       0
# domain       0
# score        0
# score_max    0
# extract      0
# author       0
# product      0
# dtype: int64

# %%
data6['score_max']=data6['score_max'].fillna(10)
data6['score']=data6['score'].fillna(0)
data6['author']=data6['author'].fillna('NA')
data6['extract']=data6['extract'].fillna('NA')
print(data6.isnull().sum())
# Out:
# phone_url    0
# date         0
# lang         0
# country      0
# source       0
# domain       0
# score        0
# score_max    0
# extract      0
# author       0
# product      0
# dtype: int64

# %% [markdown]
# Merging the provided CSVs into one data-frame

# %%
result=data1.append(data2)

# %%
result=result.append(data3)
result=result.append(data4)
result=result.append(data5)
result=result.append(data6)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415132 entries, 0 to 163836
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415132 non-null  object
#  1   date       1415132 non-null  object
#  2   lang       1415132 non-null  object
#  3   country    1415132 non-null  object
#  4   source     1415132 non-null  object
#  5   domain     1415132 non-null  object
#  6   score      1415132 non-null  float64
#  7   score_max  1415132 non-null  float64
#  8   extract    1415132 non-null  object
#  9   author     1415132 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 129.6+ MB

# %% [markdown]
# Resetting index in dataframe

# %%
result.reset_index(inplace=True)

# %%
result.drop(['index'], axis='columns', inplace=True)

# %%
result.drop_duplicates(inplace=True)

# %% [markdown]
# Dropping duplicate rows

# %%
duplicate= result.duplicated()

# %%
duplicate
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1415127    False
# 1415128    False
# 1415129    False
# 1415130    False
# 1415131    False
# Length: 1408696, dtype: bool

# %%
duplicate.any()
# Out:
# False

# %%
for i in duplicate.index:
    if duplicate[i]:
        print(i)
        print(result.iloc[i])

# %%
sampleData=result.sample(n=1000000, random_state=612)

# %%
sampleData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000000 entries, 430175 to 242141
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1000000 non-null  object
#  1   date       1000000 non-null  object
#  2   lang       1000000 non-null  object
#  3   country    1000000 non-null  object
#  4   source     1000000 non-null  object
#  5   domain     1000000 non-null  object
#  6   score      1000000 non-null  float64
#  7   score_max  1000000 non-null  float64
#  8   extract    1000000 non-null  object
#  9   author     1000000 non-null  object
#  10  product    1000000 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 91.6+ MB

# %% [markdown]
# Dropping unwanted features and keeping only 1000000 data samples. Using random state=612.

# %%
final_data=sampleData.drop(['phone_url','date','lang','country','source','domain','score_max','extract'], axis='columns')

# %%
final_data
# Out:
#          score                  author  \
# 430175     8.0  Vinod Kumar Chengespur
# 587153     2.0                  Sharon
# 594786     8.0             An Sionnach
# 636378     2.0             Jomine Jose
# 684531    10.0           Marcos Rivero
# ...        ...                     ...
# 1002309    6.0            ÐÐ½Ð´ÑÐµÐ¹
# 1111094    8.0           GEORGESDEBOTE
# 243653    10.0                   e-bit
# 92037      8.0         Client d'Amazon
# 242141     4.0                    JYLA
#
#                                                    product
# 430175                    Lenovo Vibe K4 Note (White,16GB)
# 587153   HTC Desire 816 Black (Virgin mobile) - 5.5 inc...
# 594786   Xperia Sony Xperia Z Ultra SIM-free Android Sm...
# 636378                                Lava Iris X5 (Black)
# 684531   Sony Xperia L C2105 White (Factory Unlocked) 4...
# ...                                                    ...
# 1002309                           Samsung S5830 Galaxy Ace
# ...

# %% [markdown]
# # 2. Most rated 5 products are given below

# %%
final_data['product'].value_counts().sort_values(ascending=False).head()
# Out:
# Lenovo Vibe K4 Note (White,16GB)     3709
# Lenovo Vibe K4 Note (Black, 16GB)    3083
# OnePlus 3 (Graphite, 64 GB)          2890
# OnePlus 3 (Soft Gold, 64 GB)         2522
# Huawei P8lite zwart / 16 GB          1895
# Name: product, dtype: int64

# %% [markdown]
# # The users with most number of reviews

# %%
final_data['author'].value_counts().sort_values(ascending=False).head()
# Out:
# Amazon Customer    54641
# NA                 43867
# Cliente Amazon     13669
# e-bit               5962
# Client d'Amazon     5499
# Name: author, dtype: int64

# %%
prodStore=final_data['product'].value_counts()
prodStore
# Out:
# Lenovo Vibe K4 Note (White,16GB)                                                                                           3709
# Lenovo Vibe K4 Note (Black, 16GB)                                                                                          3083
# OnePlus 3 (Graphite, 64 GB)                                                                                                2890
# OnePlus 3 (Soft Gold, 64 GB)                                                                                               2522
# Huawei P8lite zwart / 16 GB                                                                                                1895
#                                                                                                                            ...
# THANSITA New Samsung Galaxy Note 3 Sm-n9005 Quad 5.7'' 13mp 4g LTE 32gb Black/gold Phone Fast Shipping                        1
# ...

# %%
authStore=final_data['author'].value_counts()
authStore
# Out:
# Amazon Customer      54641
# NA                   43867
# Cliente Amazon       13669
# e-bit                 5962
# Client d'Amazon       5499
#                      ...
# R.H. "Pepsionice"        1
# Backlash                 1
# marcos fernandes         1
# Raptorhn                 1
# victoria price           1
# Name: author, Length: 596751, dtype: int64

# %%
prod_50=prodStore.loc[prodStore>50]

# %%
auth_50=authStore.loc[authStore>50]

# %%
prod_50
# Out:
# Lenovo Vibe K4 Note (White,16GB)                                                                                   3709
# Lenovo Vibe K4 Note (Black, 16GB)                                                                                  3083
# OnePlus 3 (Graphite, 64 GB)                                                                                        2890
# OnePlus 3 (Soft Gold, 64 GB)                                                                                       2522
# Huawei P8lite zwart / 16 GB                                                                                        1895
#                                                                                                                    ...
# Samsung Nexus S GT-I9023                                                                                             51
# Sony Xperia XCompact Smartphone (11,7 cm (4,6 Zoll), 32 GB Speicher, Android 6.0) Mist Blue                          51
# ...

# %%
prod_grp=final_data.loc[final_data['product']==prod_50.index[0]]
prod_grp=prod_grp.append(final_data.loc[final_data['product']==prod_50.index[1]])
prod_grp.drop_duplicates(inplace=True)
prod_grp
# Out:
#         score                   author                            product
# 430175    8.0   Vinod Kumar Chengespur   Lenovo Vibe K4 Note (White,16GB)
# 428727   10.0  Chiranjivi Girish Thuse   Lenovo Vibe K4 Note (White,16GB)
# 423897    8.0                    sunil   Lenovo Vibe K4 Note (White,16GB)
# 428677    2.0            Animesh Ghosh   Lenovo Vibe K4 Note (White,16GB)
# 432164    2.0          Amazon Customer   Lenovo Vibe K4 Note (White,16GB)
# ...       ...                      ...                                ...
# 424299    2.0                 jkchavda  Lenovo Vibe K4 Note (Black, 16GB)
# 426903   10.0         rajesh devisetti  Lenovo Vibe K4 Note (Black, 16GB)
# 429962   10.0          Rushikesh Kolhe  Lenovo Vibe K4 Note (Black, 16GB)
# 426447   10.0               Rietesh P.  Lenovo Vibe K4 Note (Black, 16GB)
# 431561    2.0  Racharla Vamshi Krishna  Lenovo Vibe K4 Note (Black, 16GB)
#
# [2848 rows x 3 columns]

# %%
prod_grp.shape
# Out:
# (155135, 3)

# %%
prod_grp.drop_duplicates(inplace=True)

# %%
prod_grp
# Out:
#          score                   author                           product
# 430175     8.0   Vinod Kumar Chengespur  Lenovo Vibe K4 Note (White,16GB)
# 428727    10.0  Chiranjivi Girish Thuse  Lenovo Vibe K4 Note (White,16GB)
# 423897     8.0                    sunil  Lenovo Vibe K4 Note (White,16GB)
# 428677     2.0            Animesh Ghosh  Lenovo Vibe K4 Note (White,16GB)
# 432164     2.0          Amazon Customer  Lenovo Vibe K4 Note (White,16GB)
# ...        ...                      ...                               ...
# 1091798   10.0             Naveen Power                 Sony Ericsson Elm
# 1092224   10.0        giblartar.vasilij                 Sony Ericsson Elm
# 1092010   10.0              dima1dima-9                 Sony Ericsson Elm
# 1092120    8.0              BOULANGERAC                 Sony Ericsson Elm
# 1092161   10.0          GeorgeSavchenko                 Sony Ericsson Elm
#
# [155135 rows x 3 columns]

# %%
prod_grp=final_data.loc[final_data['product']==prod_50.index[0]]
for p in range(1,4256):
    prod_grp=prod_grp.append(final_data.loc[final_data['product']==prod_50.index[p]])
    prod_grp.drop_duplicates(inplace=True)

# %%
for p in auth_50.index:
    prod_grp=prod_grp.append(final_data.loc[final_data['author']==p])
    prod_grp.drop_duplicates(inplace=True)

# %%
prod_grp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 524655 entries, 430175 to 653242
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   score    524655 non-null  float64
#  1   author   524655 non-null  object
#  2   product  524655 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 16.0+ MB

# %%
prod_grp.drop_duplicates(inplace=True)

# %% [markdown]
# # The data with products having more than 50 ratings and users who have given more than 50 ratings

# %%
prod_grp
# Out:
#          score                   author  \
# 430175     8.0   Vinod Kumar Chengespur
# 428727    10.0  Chiranjivi Girish Thuse
# 423897     8.0                    sunil
# 428677     2.0            Animesh Ghosh
# 432164     2.0          Amazon Customer
# ...        ...                      ...
# 1363771    9.0                   Jordan
# 1384457    6.0                   Jordan
# 744205    10.0                   Jordan
# 1363333    9.0                   Jordan
# 653242     8.0                   Jordan
#
#                                           product
# 430175           Lenovo Vibe K4 Note (White,16GB)
# 428727           Lenovo Vibe K4 Note (White,16GB)
# 423897           Lenovo Vibe K4 Note (White,16GB)
# 428677           Lenovo Vibe K4 Note (White,16GB)
# 432164           Lenovo Vibe K4 Note (White,16GB)
# ...                                           ...
# 1363771                          Samsung SCH-A930
# 1384457                 Motorola V325i Cell Phone
# ...

# %% [markdown]
# # The shape of the final dataset is given is 524655 rows × 3 columns

# %%
prod_grp.groupby('product')['score'].mean().sort_values(ascending=False).head()
# Out:
# product
# Nokia 1200 blue (Organizer, 3 Spiele) Handy                                                        10.0
# Nokia Lumia 1520 32GB 4G Nero                                                                      10.0
# Nokia Lumia 635 Smartphone, 8 GB, Bianco [Italia]                                                  10.0
# Nokia Lumia 635 8GB Unlocked GSM 4G LTE Windows 8.1 Quad-Core Phone - White                        10.0
# Nokia Lumia 635 8GB Unlocked GSM 4G LTE Windows 8.1 Quad-Core Phone - Nero,cassa del caso cover    10.0
# Name: score, dtype: float64

# %% [markdown]
# # The top 5 mobile phones from popularity based model
#
# Nokia 1200 blue (Organizer, 3 Spiele) Handy
# Nokia Lumia 1520 32GB 4G Nero
# Nokia Lumia 635 Smartphone, 8 GB, Bianco [Italia]
# Nokia Lumia 635 8GB Unlocked GSM 4G LTE Windows 8.1 Quad-Core Phone - White
# Nokia Lumia 635 8GB Unlocked GSM 4G LTE Windows 8.1 Quad-Core Phone - Nero,cassa del caso cover

# %%
from sklearn.preprocessing import LabelEncoder   # import label encoder

labelUser = LabelEncoder()
labelProd = LabelEncoder()
prod_grp['UserId'] = labelUser.fit_transform(prod_grp.author)

# %% [markdown]
# Building a collaborative filtering model using SVD
#
# Labeling the authors and products

# %%
prod_grp['ProductId'] = labelProd.fit_transform(np.ravel(prod_grp['product']))
      
# np.ravel(prod_grp['product']).shape

# %%
prod_grp1=prod_grp.drop(['author','product'], axis='columns')

# %%
prod_grp1
# Out:
#          score  UserId  ProductId
# 430175     8.0  213820      11224
# 428727    10.0   39451      11224
# 423897     8.0  317310      11224
# 428677     2.0   16857      11224
# 432164     2.0   13111      11224
# ...        ...     ...        ...
# 1363771    9.0  101324      22045
# 1384457    6.0  101324      13342
# 744205    10.0  101324       6668
# 1363333    9.0  101324      23080
# 653242     8.0  101324       6531
#
# [524655 rows x 3 columns]

# %%
from collections import defaultdict

from surprise import SVD
from surprise import Dataset
from surprise import Reader

# %%
reader = Reader(rating_scale=(0, 10))

# %%
data = Dataset.load_from_df(prod_grp1[['UserId', 'ProductId', 'score']], reader)

# %%
from surprise.model_selection import train_test_split

trainset, testset = train_test_split(data, test_size=.2)

# %%
algo = SVD()

# %%
algo.fit(trainset)
predictions = algo.test(testset)

# %%
predictions
# Out:
# [Prediction(uid=332108, iid=9813, r_ui=8.0, est=7.619619032180249, details={'was_impossible': False}),
#  Prediction(uid=49526, iid=2515, r_ui=2.0, est=5.796387461338838, details={'was_impossible': False}),
#  Prediction(uid=203394, iid=1949, r_ui=10.0, est=9.40155369888648, details={'was_impossible': False}),
#  Prediction(uid=36246, iid=13948, r_ui=10.0, est=8.69453294762487, details={'was_impossible': False}),
#  Prediction(uid=89720, iid=20077, r_ui=8.0, est=8.199360247576516, details={'was_impossible': False}),
#  Prediction(uid=320884, iid=10338, r_ui=4.0, est=6.954473492861082, details={'was_impossible': False}),
#  Prediction(uid=139693, iid=17598, r_ui=8.0, est=8.697433482198994, details={'was_impossible': False}),
#  Prediction(uid=135348, iid=12912, r_ui=10.0, est=8.026006304929567, details={'was_impossible': False}),
#  Prediction(uid=64703, iid=3469, r_ui=4.0, est=7.091815000346537, details={'was_impossible': False}),
# ...

# %%
from surprise import accuracy
accuracy.rmse(predictions)
# Out:
# RMSE: 2.6713
# 2.6712704246754067

# %%
# trainset.ur

# %% [markdown]
# Build a collaborative filtering model using kNNWithMeans from surprise
#
# Due to memory constraints 10000 samples are only taken

# %%
prod_grp2=prod_grp1.sample(n=10000, random_state=612)
data = Dataset.load_from_df(prod_grp2[['UserId', 'ProductId', 'score']], reader)
trainset, testset = train_test_split(data, test_size=.2)

# %%
from surprise import KNNWithMeans

# %%
algo1 = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
algo1.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# testset

# %%
test_pred = algo1.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid=264150, iid=16556, r_ui=0.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=323441, iid=6977, r_ui=4.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=80427, iid=23973, r_ui=6.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=113029, iid=6256, r_ui=8.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=243580, iid=14026, r_ui=8.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=301675, iid=16595, r_ui=9.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=342186, iid=13897, r_ui=8.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...

# %%
# get RMSE
print("User-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# User-based Model : Test Set
# RMSE: 2.8789
# 2.8789349162009343

# %% [markdown]
# As less samples are taken for KNN model gives was impossible true for many entries in test set

# %%
algo1 = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': False})
algo1.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred = algo1.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid=264150, iid=16556, r_ui=0.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=323441, iid=6977, r_ui=4.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=80427, iid=23973, r_ui=6.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=113029, iid=6256, r_ui=8.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=243580, iid=14026, r_ui=8.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=301675, iid=16595, r_ui=9.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid=342186, iid=13897, r_ui=8.0, est=7.732, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
# ...

# %%
# get RMSE
print("User-based Model : Test Set")
accuracy.rmse(test_pred, verbose=True)
# Out:
# User-based Model : Test Set
# RMSE: 2.8569
# 2.8568871665597917

# %% [markdown]
# # Answer 10
# Popularity based Recommendation Systems is used when no information is available about user preferences or user.
# It is also used when user features are not related to any other user in training data set in case of user based recommendation.
# In case of product based recommendation when product feature are not related to other products in the training data set also popularity based recommendation is used.

# %% [markdown]
# # Answer 11
# CF based Recommendation Systems is used when relation found between about users or products.

# %% [markdown]
# # Answer 12
# Content based Recommendation Systems can also be used for further improving the recommendation system.
